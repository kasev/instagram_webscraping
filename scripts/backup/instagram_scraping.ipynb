# %% [markdown]
# This notebook is dedicated to scrapping Instagram data on the basis of a hashtag. It is freely based upon a tutorial [here](https://medium.com/@kseniatikhomirova/scrap-instagram-locations-with-python-d48ba6e56ebc).
#
# I have developed it with the hashtag "vanlife", since me and my wife have been interested in geography of this phenomenon.

# %%
import pandas as pd
import sys

### we do a lot of requests during the scrapping. Some of them with requests package, some of them with urllib
import requests
from urllib.request import urlopen 
from urllib.parse import quote  
from bs4 import BeautifulSoup

# to avoid errors, we sometime use time.sleep(N) before retrying a request
import time
# the input data have typically a json structure
import json
import ast

import datetime as dt
import googlemaps


from concurrent.futures import ThreadPoolExecutor

import sddk
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
conf = sddk.configure()
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# endpoint variable has been configured to: https://sciencedata.dk/files/

# %%
# google maps - read the key from sciencedata.
key = sddk.read_file("Google_API_key.txt", "str", conf)
gmaps = googlemaps.Client(key=key)

# %%
# further, to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:

# (1) read the file and parse its content
file_data = conf[0].get(conf[1] + "ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)
# (5) establish connection with spreadsheets specified by their url
#PIA_data = gc.open_by_url()

# %% [markdown]
# # simple test

# %%
# count hashtag instances
hashtag = "vanlife"
url = "https://www.instagram.com/explore/tags/{0}/?__a=1".format(hashtag)
r = requests.get(url)
data = json.loads(r.text)
hashtag_count = data['graphql']['hashtag']['edge_hashtag_to_media']['count']
hastag_data_pages = hashtag_count / 75 # there is 75 instances per page
hashtag_count
# Out:
# 7988163

# %%
data['graphql']['hashtag']['edge_hashtag_to_media']["edges"][0]
# Out:
# {'node': {'comments_disabled': False,
#   '__typename': 'GraphImage',
#   'id': '2384271892418991390',
#   'edge_media_to_caption': {'edges': [{'node': {'text': 'Found myself a rock...\n\n#scotlandhighlands #scotlandtravel #vanlife #vwcamper #vwt5camper #homeiswhereyouparkit #vanlifediaries #roadtrip #roadtrippin #roadtripping #nc500 #highlands #campervan #camper #camperlife #staycation #staycation2020'}}]},
#   'shortcode': 'CEWoqdblRUe',
#   'edge_media_to_comment': {'count': 0},
#   'taken_at_timestamp': 1598447380,
#   'dimensions': {'height': 720, 'width': 1080},
#   'display_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=5b193c9d9e6acf45cbcfe7b82db74789&oe=5F6F4E0D',
#   'edge_liked_by': {'count': 0},
#   'edge_media_preview_like': {'count': 0},
#   'owner': {'id': '21499756140'},
#   'thumbnail_src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c200.0.800.800a/s640x640/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=1b06a3e6f68c2b8de09cf8631dd384da&oe=5F7111AA',
#   'thumbnail_resources': [{'src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/e35/c200.0.800.800a/s150x150/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=47a54ea1352bd578e3d3b20b2d3c6971&oe=5F7153EF',
#     'config_width': 150,
#     'config_height': 150},
#    {'src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/e35/c200.0.800.800a/s240x240/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=adaba56ee911bedb95455327f724824f&oe=5F70E1E9',
#     'config_width': 240,
#     'config_height': 240},
#    {'src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/e35/c200.0.800.800a/s320x320/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=a3d5b5b2285b8946c7b2bb0365223275&oe=5F6FFA97',
#     'config_width': 320,
#     'config_height': 320},
#    {'src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/e35/c200.0.800.800a/s480x480/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=0bb7205863097dfe56d2c63d711182dd&oe=5F718DD2',
#     'config_width': 480,
#     'config_height': 480},
#    {'src': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c200.0.800.800a/s640x640/118525211_138910461227100_8173299029769477163_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_cat=100&_nc_ohc=pjYSNOwPN90AX9lCt2d&oh=1b06a3e6f68c2b8de09cf8631dd384da&oe=5F7111AA',
#     'config_width': 640,
#     'config_height': 640}],
#   'is_video': False,
#   'accessibility_caption': 'Photo by Hannah Caitlin in North Coast 500.'}}

# %%
### maximal pages value
int(hastag_data_pages - 1)
# Out:
# 106507

# %% [markdown]
# # Collecting end_cursors

# %%
def request_for_next_page(url): 
    r = requests.get(url)
    try:
        data = json.loads(r.text)
        end_cursor = data['graphql']['hashtag']['edge_hashtag_to_media']['page_info']['end_cursor']
    except:
        problem = "problem"
        print(problem)
        n = 0
        while (n <= 3 and problem == "problem"):  
            time.sleep(1)
            try: 
                r = requests.get(url)
                data = json.loads(r.text)
                end_cursor = data['graphql']['hashtag']['edge_hashtag_to_media']['page_info']['end_cursor']
                problem = "problem solved"
            except:
                n = n+1
    try:
        return end_cursor
    except:
        return "not-found"

# %%
# read the latest end_cursors file

try:
    # if we already have some endcursors data, we will start with them
    all_end_cursors = sorted([fn for fn in sddk.list_filenames("instagram_webscraping", "", conf) if "end_cursors" in fn])
    latest_end_cursors = all_end_cursors[-1]
    print("latest file: " + latest_end_cursors)
    end_cursors = sddk.read_file("instagram_webscraping/" + latest_end_cursors, "list", conf)
    print(len(end_cursors))
except:
    # otherwise we will start with an empty list
    end_cursors = []
    print("starting with empty list")
# Out:
# latest file: end_cursors_2.json
# 637

# %%
# %%time
n_of_pages = 50000
hashtag = "vanlife"
raw_url =  "https://www.instagram.com/explore/tags/" + hashtag + "/?__a=1"

end_cursor = ""

for n_page in range(n_of_pages):
    if len(end_cursors) > 0:
        url = raw_url + "&max_id=" + end_cursors[-1] # use the last end cursor
    else:
        url = raw_url
    actual_end_cursor = request_for_next_page(url)
    if actual_end_cursor !="not-found":
        end_cursors.append(actual_end_cursor)# value for the next page
    else:
        break

# %%
# always change name to by increasing the number
sddk.write_file("instagram_webscraping/end_cursors_3.json", end_cursors, conf)

# %% [markdown]
# # Define crucial functions

# %%
# simple test of gmaps api
gplace = gmaps.geocode("chotikov")[0]
coordinates = gplace["geometry"]["location"]
g_loc_type = gplace["types"]
coordinates
# Out:
# {'lat': 49.792952, 'lng': 13.3176738}

# %%
def mine_the_post(actual_url):
    post_data = json.loads(requests.get(actual_url).content)
    post_mined = {}
    try:
        post_mined["location_slug"] = post_data['graphql']['shortcode_media']['location']['slug']
        address_json = post_data['graphql']['shortcode_media']['location']['address_json'].replace("false", "False").replace("true", "True") 
        address_json = ast.literal_eval(address_json.replace("false", "False").replace("true", "True"))
        post_mined["country_code"] = address_json["country_code"]
        for loc_type in ["city", "region", "country"]:
            if address_json['exact_' + loc_type + "_match"] == True:
                post_mined["i_loc_type"] = loc_type
                break
        gplace = gmaps.geocode(post_mined["location_slug"])[0]
        post_mined["coordinates"] = gplace["geometry"]["location"]
        post_mined["g_loc_type"] = gplace["types"]
    except:
        pass
        #post["location_slug" = ""
        #coordinates = None
        #i_loc_type = None
        #g_loc_type = None
    try:
        timestamp = post_data['graphql']['shortcode_media']['taken_at_timestamp']
        post_mined["timestamp"] = dt.datetime.fromtimestamp(int(timestamp)).strftime('%Y-%m-%d %H:%M:%S')
    except: pass 
    return post_mined
    #return [timestamp, location_slug, address_json, i_loc_type, , coordinates, g_loc_type] #, coordinates] #, lat, lon]

def deEmojify(inputString): # from here: https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python
  return inputString.encode('ascii', 'ignore').decode('ascii')

def get_post_info(item):
    post = {}
    item_node_shortcode = item["node"]['shortcode']
    post_url = "https://www.instagram.com/p/" + item_node_shortcode + "/?__a=1"
    post["end_cursor"] = end_cursor
    post["url"] = post_url.partition("?__a=1")[0]
    try: 
        text = item['node']['edge_media_to_caption']['edges'][0]['node']['text'].replace("\n", " ")
        post["text"] = deEmojify(text)
    except: text = ""
    hashtags = []
    for word in text.split():
        if word.startswith("#"):
            hashtags.append(word.partition("#")[2])
    post["hashtags"] = hashtags
    try: # produce a list of potential object on the picture
        caption = item['node']['accessibility_caption'].partition("contain: ")[2].split(", ")
        post["caption"] = caption[:-1] + caption[-1].split(" and ")
    except: pass
    post["likes"] = item['node']['edge_liked_by']["count"]
    #basic_data = [end_cursor, post_url.partition("?__a=1")[0], text, hashtags, caption, likes]
    try:
        post.update(mine_the_post(post_url))
    except:
        time.sleep(2)
        try: 
            post.update(mine_the_post(post_url))
        except:
            pass
    return post

def get_edges(url_address):
  try: 
    r = requests.get(url_address)
    data = json.loads(r.text)
    edges = data['graphql']['hashtag']['edge_hashtag_to_media']['edges']
    return edges
  except: 
    try:
      time.sleep(3)
      r = requests.get(url_address)
      data = json.loads(r.text)
      edges = data['graphql']['hashtag']['edge_hashtag_to_media']['edges'] # list with posts
      return edges
    except:
      return "no edges"

# %%
actual_url = "https://www.instagram.com/p/CETwJWGpuv9/?__a=1"
post_data = json.loads(requests.get(actual_url).content)
post_data['graphql']['shortcode_media']
# Out:
# {'__typename': 'GraphImage',
#  'id': '2383460376250870781',
#  'shortcode': 'CETwJWGpuv9',
#  'dimensions': {'height': 937, 'width': 750},
#  'gating_info': None,
#  'fact_check_overall_rating': None,
#  'fact_check_information': None,
#  'sensitivity_friction_info': None,
#  'media_overlay_info': None,
#  'media_preview': '',
#  'display_url': 'https://scontent-frt3-2.cdninstagram.com/v/t51.2885-15/e35/118166396_518776635599619_7755558974607652392_n.jpg?_nc_ht=scontent-frt3-2.cdninstagram.com&_nc_cat=103&_nc_ohc=CrAmHJyYrxoAX-Y4XED&oh=604abf41c207304974bb246760ab6d97&oe=5F70E2AB',
#  'display_resources': [{'src': 'https://scontent-frt3-2.cdninstagram.com/v/t51.2885-15/sh0.08/e35/p640x640/118166396_518776635599619_7755558974607652392_n.jpg?_nc_ht=scontent-frt3-2.cdninstagram.com&_nc_cat=103&_nc_ohc=CrAmHJyYrxoAX-Y4XED&oh=4bfdd260d299c547afd581b4f0714e52&oe=5F6EC3C1',
#    'config_width': 640,
#    'config_height': 800},
#   {'src': 'https://scontent-frt3-2.cdninstagram.com/v/t51.2885-15/e35/118166396_518776635599619_7755558974607652392_n.jpg?_nc_ht=scontent-frt3-2.cdninstagram.com&_nc_cat=103&_nc_ohc=CrAmHJyYrxoAX-Y4XED&oh=604abf41c207304974bb246760ab6d97&oe=5F70E2AB',
#    'config_width': 750,
#    'config_height': 937},
#   {'src': 'https://scontent-frt3-2.cdninstagram.com/v/t51.2885-15/e35/118166396_518776635599619_7755558974607652392_n.jpg?_nc_ht=scontent-frt3-2.cdninstagram.com&_nc_cat=103&_nc_ohc=CrAmHJyYrxoAX-Y4XED&oh=604abf41c207304974bb246760ab6d97&oe=5F70E2AB',
#    'config_width': 1080,
#    'config_height': 1350}],
#  'accessibility_caption': 'Photo by camper van in Los Angeles, California with @camper.lifestyle, @vanlifecamper, @camper_vibe, @camper_culture, @camper_van_conversions, @camper_vancation, @camperize, @ourrelaycamper, @campervan.gram, and @camper_van_world. Image may contain: indoor.',
#  'is_video': False,
#  'tracking_token': 'eyJ2ZXJzaW9uIjo1LCJwYXlsb2FkIjp7ImlzX2FuYWx5dGljc190cmFja2VkIjpmYWxzZSwidXVpZCI6ImM2NTQzMzc5OTliMDRiYTBiYWIyYjgwYThiNWYwMWQ4MjM4MzQ2MDM3NjI1MDg3MDc4MSJ9LCJzaWduYXR1cmUiOiIifQ==',
#  'edge_media_to_tagged_user': {'edges': [{'node': {'user': {'full_name': '🏕Vanlife | Wanderlust | Camper',
#       'id': '5682914528',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/34358031_177554336251145_6036066176449118208_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=tBusFlyHTpgAX-6NGXv&oh=0013297c6901b7389e899c62d6fa03e3&oe=5F70FBF3',
#       'username': 'vanlifecamper'},
#      'x': 0.9360666,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'Camper Lifestyle',
#       'id': '3589559856',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/32729242_748078552246401_137154098356027392_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=u9T0peyQA9UAX90jlbG&oh=620d05c44785b461469a6cbaa9f6ecd5&oe=5F702893',
#       'username': 'camper.lifestyle'},
#      'x': 0.9362688,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'Camper Culture',
#       'id': '17052492985',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/73154448_2451481375091198_5501401224076853248_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=1ZeEkn9ERpsAX-O0ePq&oh=d670ffd14661598b2195efc7dd0be579&oe=5F7090D6',
#       'username': 'camper_culture'},
#      'x': 0.9362688,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'VA(N)CATION 😎🚐',
#       'id': '24370127546',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/74345219_2148395118799837_5323545047801528320_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=IewyD8kt-_UAX8WOsH2&oh=93debf011824a93365d31b1eacc8c551&oe=5F6E7B43',
#       'username': 'camper_vancation'},
#      'x': 0.9360203,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'Louise, Emily and AJ the dog.',
#       'id': '8691630246',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/116778440_347715002891280_7629269709566757511_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=ubSG0mIzg28AX9p1ZG3&oh=eb98ef1e495dc64e975e6fe8723b90b1&oe=5F6F0E66',
#       'username': 'camper_vibe'},
#      'x': 0.8750878,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'CAMPER VAN CONVERSIONS 🚐',
#       'id': '21063615272',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/103371519_616079925783229_8035707751316418016_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=S-hIU_EElJsAX-fsdyy&oh=83f0fd218cda34b1f54ab7fafe214b33&oe=5F6E61A8',
#       'username': 'camper_van_conversions'},
#      'x': 0.9362688,
#      'y': 0.98654515}},
#    {'node': {'user': {'full_name': 'Camperize',
#       'id': '34351847822',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/103861524_3053144148054272_6843233190621650206_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=Tm_kT8RBT0sAX-68gnD&oh=2df830e9645d88e409aa6b18b02cfa4f&oe=5F6E6403',
#       'username': 'camperize'},
#      'x': 0.85424966,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'Our Relay Camper Build 🚐🔨',
#       'id': '40379140964',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/117801221_118606273067340_3603957458034044655_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=prJp9Cu-24IAX8SPGOR&oh=8dcac7f768673626b36f6eeaf4ebf0f4&oe=5F6E6D8B',
#       'username': 'ourrelaycamper'},
#      'x': 0.9362688,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': '',
#       'id': '40651041417',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/118194578_644470999541053_1351887698133899923_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=Dgt7RGv__XYAX8Ceasz&oh=90a46b01448bf66febc6bcdbeadcdcc7&oe=5F710596',
#       'username': 'camper_van_world'},
#      'x': 0.9362688,
#      'y': 0.98703706}},
#    {'node': {'user': {'full_name': 'Campervan.gram',
#       'id': '40420428723',
#       'is_verified': False,
#       'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/118202684_162707845432275_5636615714773661628_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=7egHs-bgJ04AX-5IpiP&oh=67f25d9b4fe1de180655f4a7ec55ee3f&oe=5F6ED0E4',
#       'username': 'campervan.gram'},
#      'x': 0.9362688,
#      'y': 0.9750051}}]},
#  'edge_media_to_caption': {'edges': [{'node': {'text': '#vanlife #camper #vwt #camping #homeiswhereyouparkit #camperlife #t #travel #vanlifediaries #van #roadtrip #vw #campervanlife #homeonwheels #vanlifers #adventure #vanconversion #vwbus #camperlifestyle #volkswagen #projectvanlife #vanlifestyle #wanderlust #vwcamper #vanlifegermany #vanlifemovement ##campervanx #nature #bhfyp'}}]},
#  'caption_is_edited': False,
#  'has_ranked_comments': False,
#  'edge_media_to_parent_comment': {'count': 0,
#   'page_info': {'has_next_page': False, 'end_cursor': None},
#   'edges': []},
#  'edge_media_to_hoisted_comment': {'edges': []},
#  'edge_media_preview_comment': {'count': 0, 'edges': []},
#  'comments_disabled': False,
#  'commenting_disabled_for_viewer': False,
#  'taken_at_timestamp': 1598350639,
#  'edge_media_preview_like': {'count': 68, 'edges': []},
#  'edge_media_to_sponsor_user': {'edges': []},
#  'location': {'id': '212999109',
#   'has_public_page': True,
#   'name': 'Los Angeles, California',
#   'slug': 'los-angeles-california',
#   'address_json': '{"street_address": "", "zip_code": "", "city_name": "Los Angeles, California", "region_name": "", "country_code": "US", "exact_city_match": true, "exact_region_match": false, "exact_country_match": false}'},
#  'viewer_has_liked': False,
#  'viewer_has_saved': False,
#  'viewer_has_saved_to_collection': False,
#  'viewer_in_photo_of_you': False,
#  'viewer_can_reshare': True,
#  'owner': {'id': '40597697387',
#   'is_verified': False,
#   'profile_pic_url': 'https://scontent-frx5-1.cdninstagram.com/v/t51.2885-19/s150x150/117717710_169277574685291_5268075130682426671_n.jpg?_nc_ht=scontent-frx5-1.cdninstagram.com&_nc_ohc=pGk7xxhv7w4AX8x-cmd&oh=88b7384b57917db4394a668a367adf83&oe=5F6F04F1',
#   'username': 'cam.pervan',
#   'blocked_by_viewer': False,
#   'restricted_by_viewer': None,
#   'followed_by_viewer': False,
#   'full_name': 'camper van',
#   'has_blocked_viewer': False,
#   'is_private': False,
#   'is_unpublished': False,
#   'requested_by_viewer': False,
#   'edge_owner_to_timeline_media': {'count': 31},
#   'edge_followed_by': {'count': 691}},
#  'is_ad': False,
#  'edge_web_media_to_related_media': {'edges': []},
#  'edge_related_profiles': {'edges': []}}

# %% [markdown]
# # Scrape end_cursors and post data at the same time

# %%
# %%time

n_of_pages = 50000
num_checks = [num for num in range(0, n_of_pages, 50)]

hashtag = "vanlife"
raw_url =  "https://www.instagram.com/explore/tags/" + hashtag + "/?__a=1"

actual_data = []
end_cursors = []
end_cursor = ""
n = 1

for n_page in range(n_of_pages):
    if len(end_cursors) > 0:
        url = raw_url + "&max_id=" + end_cursors[-1] # use the last end cursor
    else:
        url = raw_url
    #url = "https://www.instagram.com/explore/tags/{0}/?__a=1&max_id={1}".format(hashtag, actual_end_cursor)
    edges = get_edges(url)
    if edges != "no edges":
        with ThreadPoolExecutor(max_workers=75) as pool:
            current_parsed_edges = list(pool.map(get_post_info,edges))
        actual_data.extend(current_parsed_edges)
    n = n+1
    if n in num_checks:
        print(n)
        actual_data_df = pd.DataFrame(actual_data)
        sddk.write_file("instagram_webscraping/posts_raw_" + str(n) + ".json", actual_data_df, conf)
        actual_data = [] # clear actual data
    
    end_cursor = request_for_next_page(url)
    if end_cursor !="not-found":
        end_cursors.append(end_cursor)# value for the next page
    else:
        break
# Out:
# 50
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_50.json"
# 100
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_100.json"
# 150
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_150.json"
# 200
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_200.json"
# 250
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_250.json"
# 300
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_300.json"
# 350
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_350.json"
# 400
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_400.json"
# 450
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_450.json"
# 500
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_500.json"
# 550
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_550.json"
# 600
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_600.json"
# 650
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_650.json"
# 700
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_700.json"
# 750
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_750.json"
# 800
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_800.json"
# 850
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_850.json"
# 900
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_900.json"
# 950
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_950.json"
# 1000
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1000.json"
# 1050
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1050.json"
# 1100
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1100.json"
# 1150
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1150.json"
# 1200
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1200.json"
# 1250
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1250.json"
# 1300
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1300.json"
# 1350
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1350.json"
# 1400
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1400.json"
# 1450
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1450.json"
# 1500
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1500.json"
# 1550
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1550.json"
# 1600
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1600.json"
# 1650
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1650.json"
# 1700
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1700.json"
# 1750
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1750.json"
# 1800
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1800.json"
# 1850
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1850.json"
# 1900
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1900.json"
# 1950
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_1950.json"
# 2000
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2000.json"
# 2050
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2050.json"
# 2100
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2100.json"
# 2150
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2150.json"
# 2200
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2200.json"
# 2250
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2250.json"
# 2300
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2300.json"
# 2350
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2350.json"
# 2400
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2400.json"
# 2450
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2450.json"
# 2500
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2500.json"
# 2550
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2550.json"
# 2600
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2600.json"
# 2650
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2650.json"
# 2700
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2700.json"
# 2750
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/instagram_webscraping/posts_raw_2750.json"

# %% [markdown]
# # Start with preprocessed end_cursor data

# %%
# %%time
num_checks = [num for num in range(0,len(end_cursors), 50)]
actual_data = []
n = 1
tag = 'vanlife' # your tag
for end_cursor in end_cursors:
    url = "https://www.instagram.com/explore/tags/{0}/?__a=1&max_id={1}".format(tag, end_cursor)
    edges = get_edges(url)
    if edges != "no edges":
      with ThreadPoolExecutor(max_workers=75) as pool:
        current_parsed_edges = list(pool.map(get_post_info,edges))
      actual_data.extend(current_parsed_edges)
    n = n+1
    if n in num_checks:
        print(n)
        print("latest end_cursor: " + end_cursor)
        actual_data_df = pd.DataFrame(actual_data)
        sddk.write_file("instagram_webscraping/posts_raw_" + str(n) + ".json", actual_data_df, conf)
        actual_data = [] # clear actual data
      #if len(actual_data) >= 5000:
      #  actual_data_df = pd.DataFrame(actual_data)
      #  sddk.write_file("instagram_webscraping/posts_raw_" + str(n) + ".json", actual_data_df, conf)
      #  n = n+1
      #  actual_data = [] # clear actual data
        
### export our last data as well 
actual_data_df = pd.DataFrame(actual_data)
sddk.write_file("instagram_webscraping/posts_raw_" + str(n) + ".json", actual_data_df, conf)#
#sddk.write_file("instagram_webscraping/posts_raw_20200826.json", actual_data_df, conf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'end_cursors' is not defined

# %%
actual_data_df
# Out:
#                                             end_cursor  \
# 0    QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 1    QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 2    QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 3    QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 4    QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# ..                                                 ...
# 350  QVFCVEFIVU4tWDluVjZuVXN4RHhjd1ZpREh1VWpJQ0ZhZ0...
# 351  QVFCVEFIVU4tWDluVjZuVXN4RHhjd1ZpREh1VWpJQ0ZhZ0...
# 352  QVFCVEFIVU4tWDluVjZuVXN4RHhjd1ZpREh1VWpJQ0ZhZ0...
# 353  QVFCVEFIVU4tWDluVjZuVXN4RHhjd1ZpREh1VWpJQ0ZhZ0...
# 354  QVFCVEFIVU4tWDluVjZuVXN4RHhjd1ZpREh1VWpJQ0ZhZ0...
#
#                                           url  \
# 0    https://www.instagram.com/p/CETwOAgILJK/
# 1    https://www.instagram.com/p/CETwMNxJWG6/
# 2    https://www.instagram.com/p/CETwJWGpuv9/
# 3    https://www.instagram.com/p/CETwJONA_9T/
# 4    https://www.instagram.com/p/CETwIInpCsg/
# ..                                        ...
# 350  https://www.instagram.com/p/CETqvCjJyDh/
# 351  https://www.instagram.com/p/CETqpYygRM2/
# 352  https://www.instagram.com/p/CETqVgbAPJY/
# 353  https://www.instagram.com/p/CERNpqgipCD/
# 354  https://www.instagram.com/p/CEPdFRklPJP/
#
#                                                   text  \
# 0    Lugares de descanso y pernocta que marcan la d...
# 1    Pippa's first holibob...and our first camping ...
# 2    #vanlife #camper #vwt #camping #homeiswhereyou...
# 3    Back to work today and missing the sea views b...
# 4    Being back in Norway meant shitty weather and ...
# ..                                                 ...
# 350  First #roadtrip with @2beealives sister. The r...
# 351  Kings Park Festival Australian Events  www.roa...
# 352  Kings Park Festival  Australian Events  www.ro...
# 353                                          Parthenay
# 354  Window cut and fitted! #kiravans #tranistcusto...
#
#                                               hashtags  \
# 0    [diasentremontañas, anayruben, subetealpaisaje...
# 1    [lakedistrict, t5, camping, campervan, hoilday...
# 2    [vanlife, camper, vwt, camping, homeiswhereyou...
# 3    [vanlife, vanlifediaries, vanlifeuk, t4, vwt4,...
# 4    [norway, hike, waterfall, lake, travel, view, ...
# ..                                                 ...
# 350  [roadtrip, vanlife, vanlifegermany, vanlifedia...
# 351  [roadtrip, australia, roadiii, vanlife, touris...
# 352  [roadtrip, australia, roadiii, vanlife, touris...
# 353                                                 []
# 354       [kiravans, tranistcustom, camper, campervan]
#
#                                                caption  likes  \
# 0                    [mountain, sky, outdoor, nature.]     39
# 1                    [mountain, sky, outdoor, nature.]     31
# 2                                            [indoor.]     65
# 3    [one or more people, ocean, sky, cloud, outdoo...     56
# 4                    [mountain, sky, outdoor, nature.]     19
# ..                                                 ...    ...
# 350        [sky, tree, plant, grass, outdoor, nature.]     35
# 351                                  [flower, nature.]     13
# 352                  [plant, flower, nature, outdoor.]     11
# 353                                 [outdoor, nature.]     39
# 354                                    [sky, outdoor.]     12
#
#                timestamp           location_slug country_code  \
# 0    2020-08-25 10:17:58                     NaN          NaN
# 1    2020-08-25 10:17:43           lake-district           GB
# 2    2020-08-25 10:17:19  los-angeles-california           US
# 3    2020-08-25 10:17:18                   wales           GB
# 4    2020-08-25 10:17:09      rago-national-park
# ..                   ...                     ...          ...
# 350  2020-08-25 09:30:02           pirna-germany           DE
# 351  2020-08-25 09:29:16                     NaN          NaN
# 352  2020-08-25 09:26:33                     NaN          NaN
# 353  2020-08-24 10:37:25               parthenay           FR
# 354  2020-08-23 18:13:47                     NaN          NaN
#
#                                   coordinates  \
# 0                                         NaN
# 1      {'lat': 35.225172, 'lng': -89.7312158}
# 2    {'lat': 34.0522342, 'lng': -118.2436849}
# 3      {'lat': 52.1306607, 'lng': -3.7837117}
# 4      {'lat': 67.4385104, 'lng': 16.0056756}
# ..                                        ...
# 350    {'lat': 50.9625175, 'lng': 13.9419168}
# 351                                       NaN
# 352                                       NaN
# 353      {'lat': 46.648825, 'lng': -0.251441}
# 354                                       NaN
#
#                                             g_loc_type i_loc_type
# 0                                                  NaN        NaN
# 1    [establishment, point_of_interest, shopping_mall]        NaN
# 2                                [locality, political]       city
# 3             [administrative_area_level_1, political]     region
# 4    [establishment, park, point_of_interest, touri...        NaN
# ..                                                 ...        ...
# 350                              [locality, political]       city
# 351                                                NaN        NaN
# 352                                                NaN        NaN
# 353                              [locality, political]       city
# 354                                                NaN        NaN
#
# [355 rows x 12 columns]

# %% [markdown]
# # To begin with parsed data

# %%
data_parsed_df = sddk.read_file("instagram_webscraping/posts_raw_1.json", "df", conf)
data_parsed_df.head(30)
# Out:
#                                                     0  \
# 0   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 1   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 2   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 3   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 4   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 5   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 6   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 7   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 8   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 9   QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 10  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 11  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 12  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 13  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 14  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 15  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 16  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 17  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 18  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 19  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 20  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 21  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 22  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 23  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 24  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 25  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 26  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 27  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 28  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
# 29  QVFCT1dLZGtyQksyekRPUlJ3LVlaTFA0WFdUQ010OE9yNl...
#
#                                            1  \
# 0   https://www.instagram.com/p/CETwOAgILJK/
# 1   https://www.instagram.com/p/CETwMNxJWG6/
# 2   https://www.instagram.com/p/CETwJWGpuv9/
# 3   https://www.instagram.com/p/CETwJONA_9T/
# 4   https://www.instagram.com/p/CETwIInpCsg/
# 5   https://www.instagram.com/p/CETwHu_jlIo/
# 6   https://www.instagram.com/p/CETwGeMjO7O/
# 7   https://www.instagram.com/p/CETwGUxJKif/
# 8   https://www.instagram.com/p/CETwEV4pa-a/
# 9   https://www.instagram.com/p/CETwCCdoOLr/
# 10  https://www.instagram.com/p/CETwAqEB-7x/
# 11  https://www.instagram.com/p/CETv_-oJp6Q/
# 12  https://www.instagram.com/p/CETv_xDpjqJ/
# 13  https://www.instagram.com/p/CETv-VynKKI/
# 14  https://www.instagram.com/p/CETv-Jcp3j_/
# 15  https://www.instagram.com/p/CETvs6vijbt/
# 16  https://www.instagram.com/p/CETv7r9ptfG/
# 17  https://www.instagram.com/p/CETv5HrB8S-/
# 18  https://www.instagram.com/p/CETv3uxj1qT/
# 19  https://www.instagram.com/p/CETv3aPAMtb/
# 20  https://www.instagram.com/p/CETv2GYoupL/
# 21  https://www.instagram.com/p/CETvz7jgJFB/
# 22  https://www.instagram.com/p/CETvvxQqKLr/
# 23  https://www.instagram.com/p/CETvuh5JDzw/
# 24  https://www.instagram.com/p/CETvqbgJbzC/
# 25  https://www.instagram.com/p/CETvrntJg_D/
# 26  https://www.instagram.com/p/CETvqjHoaQG/
# 27  https://www.instagram.com/p/CETvm9rphuJ/
# 28  https://www.instagram.com/p/CETvkywp7-j/
# 29  https://www.instagram.com/p/CETvj4DjAmc/
#
#                                                     2  \
# 0   Lugares de descanso y pernocta que marcan la d...
# 1   Pippa's first holibob...and our first camping ...
# 2   #vanlife #camper #vwt #camping #homeiswhereyou...
# 3   Back to work today and missing the sea views b...
# 4   Being back in Norway meant shitty weather and ...
# 5   Visite de Rocamadour au top !!  #rocamadour #d...
# 6   Golden hour is our happy hour   This great cam...
# 7   Deutschland-Tour Tag 5-7:  Am Abend des fnften...
# 8   A small sign of life from us - were fine .  #c...
# 9   ()Wir sind nicht die Norm, wir sind die die an...
# 10  Took the van for a 1st little spin out managed...
# 11  Nchste Woche beginnt unsere erste groe Reise m...
# 12  You may have noticed that a couple of the prod...
# 13  Been working as a delivery driver for about a ...
# 14  #erbaa #toptan #hanmlarpasaj #yapraksarmas #ya...
# 15  Todoooo para nosotr@s solit@s!!! Son las 7:00 ...
# 16   except for memories, nothing you see will rem...
# 17  Valle de Aezkoa, Navarra.   #valleaezkoa #selv...
# 18  Lets be clear: living with PTSD is very differ...
# 19  I'm not in Scotland. But i'm on a little trip ...
# 20                      Weiter geht's mit dem Heinz!
# 21                    N.T now youre just showing off!
# 22  Appena tornati dalla nostra prima vacanza in v...
# 23                      la vraie vie part II #vanlife
# 24  Last night's camping place is one of a kind . ...
# 25  filzen... Filzen..! FILZEN!!! Part #2  Wegen "...
# 26  Two things I detest.. going to the doctors or ...
# 27  Eine der vielen Schluchten bei Slovensky raj i...
# 28  Should've brought my waterproofs. Good old Wal...
# 29  Hurra, DPD war da   [... Werbung] #opel #movan...
#
#                                                     3  \
# 0   [diasentremontaas, anayruben, subetealpaisaje,...
# 1   [lakedistrict, t5, camping, campervan, hoilday...
# 2   [vanlife, camper, vwt, camping, homeiswhereyou...
# 3   [vanlife, vanlifediaries, vanlifeuk, t4, vwt4,...
# 4   [norway, hike, waterfall, lake, travel, view, ...
# 5   [rocamadour, decouverte, campingcar, campingca...
# 6   [InsiderTip, jaycoaustralia, camping, roadtrip...
# 7   [mecklenburgvorpommern, mecklenburgischeseenpl...
# 8   [campershower, outdoorshower, campervan, campe...
# 9   [frmehrrealittaufinstagram, formorerealityonin...
# 10  [vwtransporter, vwcampervan, vanlife, vanlifef...
# 11  [camperausbau, campervans, camper, camperdiy, ...
# 12  [sounddeadening, dodomat, insulation, camperco...
# 13  [asdadeliverydriver, openuniversitystudent, va...
# 14  [erbaa, toptan, hanmlarpasaj, yapraksarmas, ya...
# 15  [camperlife, campervan, wesfalia, camperizacio...
# 16                                                 []
# 17  [valleaezkoa, selvadeirati, pirineonavarro, pi...
# 18                                          [VanLife]
# 19  [scapecaptures, visitscotland, scotland, lands...
# 20                                                 []
# 21                                                 []
# 22  [vanlife, vanlifeing, vanlifevirals, vannation...
# 23                                          [vanlife]
# 24  [camping, travelling, vanlifeinourbiggy, lovet...
# 25  [2, camperausbau, orange, vanlifeideas, myhome...
# 26  [classicvan, classiccamper, vanconversion, van...
# 27  [vanlife, selfmadecampervan, camperlifestyle, ...
# 28  [vanlife, Wales, breconbeacons, rain, dontfanc...
# 29  [opel, movano, vanlife, travel, transporter, f...
#
#                                                     4    5  \
# 0                   [mountain, sky, outdoor, nature.]   30
# 1                   [mountain, sky, outdoor, nature.]   23
# 2                                           [indoor.]   55
# 3   [one or more people, ocean, sky, cloud, outdoo...   36
# 4                   [mountain, sky, outdoor, nature.]   14
# 5                              [cloud, sky, outdoor.]   13
# 6                             [sky, outdoor, nature.]   18
# 7                                     [food, indoor.]   60
# 8                            [tree, outdoor, nature.]  111
# 9        [sky, cloud, ocean, outdoor, water, nature.]   49
# 10                          [1 person, sitting, dog.]   16
# 11                                          [indoor.]   98
# 12       [text that says 'od ery experts dodomatuk'.]   46
# 13              [coffee cup, coffee, drink, outdoor.]   14
# 14                                            [food.]   14
# 15                                                      17
# 16                                                 []  163
# 17                          [1 person, car, outdoor.]   75
# 18                                                 []  101
# 19           [cloud, sky, mountain, outdoor, nature.]   42
# 20              [sky, ocean, outdoor, nature, water.]   42
# 21      [sky, plant, flower, grass, outdoor, nature.]   51
# 22                 [tree, sky, car, outdoor, nature.]  454
# 23                                         [outdoor.]   29
# 24                                                      51
# 25                                        [1 person.]   16
# 26                                  [people sitting.]   10
# 27                                         [outdoor.]   34
# 28                                                 []    9
# 29                            [plant, tree, outdoor.]    6
#
#                       6   7  \
# 0   2020-08-25 10:17:58
# 1   2020-08-25 10:17:43  GB
# 2   2020-08-25 10:17:19  US
# 3   2020-08-25 10:17:18  GB
# 4   2020-08-25 10:17:09
# 5   2020-08-25 10:17:06  FR
# 6   2020-08-25 10:16:56  AU
# 7   2020-08-25 10:16:55
# 8   2020-08-25 10:16:38
# 9   2020-08-25 10:16:19  NL
# 10  2020-08-25 10:16:08
# 11  2020-08-25 10:16:03
# 12  2020-08-25 10:16:01
# 13  2020-08-25 10:15:49
# 14  2020-08-25 10:15:48
# 15  2020-08-25 10:15:31
# 16  2020-08-25 10:15:27
# 17  2020-08-25 10:15:06
# 18  2020-08-25 10:14:55  GB
# 19  2020-08-25 10:14:52
# 20  2020-08-25 10:14:42  DK
# 21  2020-08-25 10:14:24  AU
# 22  2020-08-25 10:13:50  IT
# 23  2020-08-25 10:13:40
# 24  2020-08-25 10:13:19  BG
# 25  2020-08-25 10:13:16
# 26  2020-08-25 10:13:07
# 27  2020-08-25 10:12:38
# 28  2020-08-25 10:12:20
# 29  2020-08-25 10:12:12
#
#                                                     8 9    10
# 0                                                None    [, ]
# 1   {'id': '113392233373458', 'has_public_page': T...    [, ]
# 2   {'id': '212999109', 'has_public_page': True, '...    [, ]
# 3   {'id': '258199373', 'has_public_page': True, '...    [, ]
# 4   {'id': '362528469', 'has_public_page': True, '...    [, ]
# 5   {'id': '250378211', 'has_public_page': True, '...    [, ]
# 6   {'id': '236913728', 'has_public_page': True, '...    [, ]
# 7                                                None    [, ]
# 8                                                None    [, ]
# 9   {'id': '248392736', 'has_public_page': True, '...    [, ]
# 10                                               None    [, ]
# 11                                               None    [, ]
# 12                                               None    [, ]
# 13                                               None    [, ]
# 14                                               None    [, ]
# 15  {'id': '24417340', 'has_public_page': True, 'n...    [, ]
# 16                                               None    [, ]
# 17  {'id': '805051286266176', 'has_public_page': T...    [, ]
# 18  {'id': '12136106', 'has_public_page': True, 'n...    [, ]
# 19                                               None    [, ]
# 20  {'id': '243629768', 'has_public_page': True, '...    [, ]
# 21  {'id': '218365897', 'has_public_page': True, '...    [, ]
# 22  {'id': '645044105561743', 'has_public_page': T...    [, ]
# 23                                               None    [, ]
# 24  {'id': '264935194', 'has_public_page': True, '...    [, ]
# 25                                               None    [, ]
# 26                                               None    [, ]
# 27                                               None    [, ]
# 28  {'id': '215032600', 'has_public_page': True, '...    [, ]
# 29                                               None    [, ]
